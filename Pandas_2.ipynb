# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav210905/Pandas-/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# DataFrames

# %%
employee1 = pd.Series({'Name': 'Utkarsh', 'ID': 1, 'Gender': 'Male', 'Salary': 95000})
employee2 = pd.Series({'Name': 'Kartik', 'ID': 2, 'Gender': 'Male', 'Salary': 85000})
employee3 = pd.Series({'Name': 'Aishwarya', 'ID': 3, 'Gender': 'Female', 'Salary': 75000})

# %%
employees = [employee1, employee2, employee3]
df1 = pd.DataFrame(employees, index=range(101, 104))
df1
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000

# %%
df1.head()
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000

# %%
df1.tail(2)
# Out:
#           Name  ID  Gender  Salary
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 101 to 103
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   ID      3 non-null      int64
#  2   Gender  3 non-null      object
#  3   Salary  3 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 228.0+ bytes

# %%
df1
# Out:
#              Name  ID  Gender  Salary
# Emp_no
# 101       Utkarsh   1    Male   95000
# 102        Kartik   2    Male   85000
# 103     Aishwarya   3  Female   75000

# %%
df1.index
# Out:
# RangeIndex(start=101, stop=104, step=1)

# %%
df1.columns
# Out:
# Index(['Name', 'ID', 'Gender', 'Salary'], dtype='object')

# %%
df1.values
# Out:
# array([['Utkarsh', 1, 'Male', 95000],
#        ['Kartik', 2, 'Male', 85000],
#        ['Aishwarya', 3, 'Female', 75000]], dtype=object)

# %%
df1.name="Employee Details"
df1.index.name="Emp_no"

# %%
df1.index.name
# Out:
# 'Emp_no'

# %%
df1.describe()
# Out:
#         ID   Salary
# count  3.0      3.0
# mean   2.0  85000.0
# std    1.0  10000.0
# min    1.0  75000.0
# 25%    1.5  80000.0
# 50%    2.0  85000.0
# 75%    2.5  90000.0
# max    3.0  95000.0

# %% [markdown]
# Access Data from DataFrame

# %%
df1["Name"]
# Out:
# Emp_no
# 101      Utkarsh
# 102       Kartik
# 103    Aishwarya
# Name: Name, dtype: object

# %%
df1[["Name","ID"]]
# Out:
#              Name  ID
# Emp_no
# 101       Utkarsh   1
# 102        Kartik   2
# 103     Aishwarya   3

# %%
df1.iloc[0]
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# Name: 101, dtype: object

# %%
df1.iloc[0]['Salary']
# Out:
# 95000

# %%
df1.loc[101].Salary
# Out:
# 95000

# %%
df1.loc[101]
# Out:
# Name      Utkarsh
# ID              1
# Gender       Male
# Salary      95000
# Name: 101, dtype: object

# %%
df1.iloc[[0,1,2]]
# Out:
#              Name  ID  Gender  Salary
# Emp_no
# 101       Utkarsh   1    Male   95000
# 102        Kartik   2    Male   85000
# 103     Aishwarya   3  Female   75000

# %%
df1.loc[[101,103]]
# Out:
#              Name  ID  Gender  Salary
# Emp_no
# 101       Utkarsh   1    Male   95000
# 103     Aishwarya   3  Female   75000

# %%
df1.loc[[101,103]][['Salary','Name']]
# Out:
#         Salary       Name
# Emp_no
# 101      95000    Utkarsh
# 103      75000  Aishwarya

# %% [markdown]
# Add and remove Functions

# %%
df1.loc[104] = ['Pranav',21,'Male',60000]
df1
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000
# 104     Pranav  21    Male   60000

# %%
df1
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000
# 104     Pranav  21    Male   60000

# %%
df1['Age']=np.random.randint(1,25,3)
df1
# Out:
#           Name  ID  Gender  Salary  Age
# 101    Utkarsh   1    Male   95000    1
# 103  Aishwarya   3  Female   75000   20
# 104     Pranav  21    Male   60000    9

# %%
df1['City']='Jaipur'
df1
# Out:
#           Name  ID  Gender  Salary    City
# 101    Utkarsh   1    Male   95000  Jaipur
# 102     Kartik   2    Male   85000  Jaipur
# 103  Aishwarya   3  Female   75000  Jaipur
# 104     Pranav  21    Male   60000  Jaipur

# %%
df1.drop(102,inplace=True,axis=0)

# %%
df1
# Out:
#           Name  ID  Gender  Salary
# 101    Utkarsh   1    Male   95000
# 102     Kartik   2    Male   85000
# 103  Aishwarya   3  Female   75000

# %%
df1.drop('City',inplace=True,axis=1)

# %%
df1
# Out:
#           Name  ID  Gender  Salary  Age
# 101    Utkarsh   1    Male   95000    1
# 103  Aishwarya   3  Female   75000   20
# 104     Pranav  21    Male   60000    9

# %%
df1[df1.Age>5]
# Out:
#           Name  ID  Gender  Salary  Age
# 103  Aishwarya   3  Female   75000   20
# 104     Pranav  21    Male   60000    9

# %%
df1[df1.Gender=="Male"]
# Out:
#         Name  ID Gender  Salary  Age
# 101  Utkarsh   1   Male   95000    1
# 104   Pranav  21   Male   60000    9

# %%
df1[df1.Salary>30000]
# Out:
#           Name  ID  Gender  Salary  Age
# 101    Utkarsh   1    Male   95000    1
# 103  Aishwarya   3  Female   75000   20
# 104     Pranav  21    Male   60000    9

# %%
df1[df1.Age>5][df1.Gender=="Male"]
# Out:
# <ipython-input-63-775a2a6d3f71>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1[df1.Age>5][df1.Gender=="Male"]
#        Name  ID Gender  Salary  Age
# 104  Pranav  21   Male   60000    9
