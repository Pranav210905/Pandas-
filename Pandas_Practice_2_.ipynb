# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav210905/Pandas-/blob/main/Pandas_Practice_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions for Pandas Assignment
# ---
# Welcome to the Pandas assignment! In this exercise, you will work with the Rick and Morty dataset to practice your data manipulation and analysis skills using Pandas. Please follow the instructions below carefully:
#
# 1. **Understand the Dataset**: The dataset used in this assignment is related to the Rick and Morty TV show. Familiarize yourself with the dataset's structure and content before starting.
#
# 2. **Read Each Question Thoroughly**: Each question in this assignment is designed to test different Pandas functionalities. Make sure you understand the requirements of each question before you begin coding.
#
# 3. **Write Your Code in the Provided Cells**: For each question, a code cell is provided where you should write your solution. Do not modify any other cells or sections of the notebook.
#
# 4. **Execute Your Code**: After writing your code in each cell, run the cell to check if your code produces the expected results. Verify that the output matches the requirements specified in the question.
#
# 5. **Complete All Questions**: Ensure that you attempt and complete all the questions provided in the notebook. Each question is designed to test different Pandas skills and concepts.
#
# 6. **Review Your Work**: Before submitting, double-check your answers and make sure all questions are addressed. Ensure that the notebook runs without errors and that all outputs are correct.
#
# 7. **Download Your Notebook**: Once you have completed all the questions and verified your solutions, download the notebook file (.ipynb). You can do this by selecting `File` > `Download` > `Download .ipynb` from the Google Colab menu.
#
# 8. **Submit Your Assignment**: Upload the downloaded .ipynb file to the designated learning platform for submission.
#
# 9. **Verify Submission**: Ensure that you have uploaded the correct file and that it is not corrupted. If you encounter any issues with the file, you may need to resubmit.
#
# ---
#
# Good luck with your assignment!

# %% [markdown]
# Q1. Import Numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Q2. Read the Characters, Episodes, and Locations datasets into Pandas DataFrames.

# %%
characters_data=pd.read_csv('/content/drive/MyDrive/characters_data.csv')
episodes_data=pd.read_csv('/content/drive/MyDrive/69_episodes_data.csv')
locations_data=pd.read_csv('/content/drive/MyDrive/locations_data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Q3. Sort the Episodes DataFrame by the Air Date column in ascending order.

# %%
episodes_data['air_date']=pd.to_datetime(episodes_data['air_date'])
episodes_data.sort_values(by='air_date',ascending=True)
# Out:
#     Unnamed: 0  id                                     name   air_date  \
# 0            0   1                                    Pilot 2013-12-02
# 1            1   2                            Lawnmower Dog 2013-12-09
# 2            2   3                             Anatomy Park 2013-12-16
# 3            3   4                   M. Night Shaym-Aliens! 2014-01-13
# 4            4   5                     Meeseeks and Destroy 2014-01-20
# 5            5   6                           Rick Potion #9 2014-01-27
# 6            6   7                      Raising Gazorpazorp 2014-03-10
# 7            7   8                            Rixty Minutes 2014-03-17
# 8            8   9          Something Ricked This Way Comes 2014-03-24
# 9            9  10     Close Rick-counters of the Rick Kind 2014-04-07
# 10          10  11                          Ricksy Business 2014-04-14
# 11          11  12                         A Rickle in Time 2015-07-26
# ...

# %% [markdown]
# Q4. Count the number of characters for each species in the Characters DataFrame

# %%
characters_data.species.value_counts()
# Out:
# species
# Human    15
# Alien     5
# Name: count, dtype: int64

# %% [markdown]
# Q5. Group the Episodes DataFrame by Season and calculate the number of episodes per season.

# %%
episodes_data['season'] = episodes_data['episode'].str[:3]
episodes_data.groupby(by="season").season.value_counts()
# Out:
# season
# S01    11
# S02     9
# Name: count, dtype: int64

# %% [markdown]
# Q.6 Filter the Characters DataFrame to show only characters who are 'Human' and have 'Alive' status.

# %%
characters_data[characters_data.species == 'Human'][characters_data.status=='Alive']
# Out:
# <ipython-input-97-59ca6ce903e9>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   characters_data[characters_data.species == 'Human'][characters_data.status=='Alive']
#     Unnamed: 0  id           name status species                 type  gender  \
# 0            0   1   Rick Sanchez  Alive   Human                  NaN    Male
# 1            1   2    Morty Smith  Alive   Human                  NaN    Male
# 2            2   3   Summer Smith  Alive   Human                  NaN  Female
# 3            3   4     Beth Smith  Alive   Human                  NaN  Female
# 4            4   5    Jerry Smith  Alive   Human                  NaN    Male
# 16          16  17          Annie  Alive   Human                  NaN  Female
# 17          17  18  Antenna Morty  Alive   Human  Human with antennae    Male
#
#                                                origin  \
# 0   {'name': 'Earth (C-137)', 'url': 'https://rick...
# ...

# %% [markdown]
# Q.7 Apply a function to convert all episode titles in the Episodes DataFrame to uppercase.

# %%
episodes_data['name'] = episodes_data.name.str.upper()
episodes_data
# Out:
#     Unnamed: 0  id                                     name   air_date  \
# 0            0   1                                    PILOT 2013-12-02
# 1            1   2                            LAWNMOWER DOG 2013-12-09
# 2            2   3                             ANATOMY PARK 2013-12-16
# 3            3   4                   M. NIGHT SHAYM-ALIENS! 2014-01-13
# 4            4   5                     MEESEEKS AND DESTROY 2014-01-20
# 5            5   6                           RICK POTION #9 2014-01-27
# 6            6   7                      RAISING GAZORPAZORP 2014-03-10
# 7            7   8                            RIXTY MINUTES 2014-03-17
# 8            8   9          SOMETHING RICKED THIS WAY COMES 2014-03-24
# 9            9  10     CLOSE RICK-COUNTERS OF THE RICK KIND 2014-04-07
# 10          10  11                          RICKSY BUSINESS 2014-04-14
# 11          11  12                         A RICKLE IN TIME 2015-07-26
# ...

# %% [markdown]
# Q.8 Filter the Characters DataFrame to show only characters with the species 'Human'.

# %%
characters_data[characters_data.species=="Human"]
# Out:
#     Unnamed: 0  id                     name   status species  \
# 0            0   1             Rick Sanchez    Alive   Human
# 1            1   2              Morty Smith    Alive   Human
# 2            2   3             Summer Smith    Alive   Human
# 3            3   4               Beth Smith    Alive   Human
# 4            4   5              Jerry Smith    Alive   Human
# 6            6   7         Abradolf Lincler  unknown   Human
# 7            7   8         Adjudicator Rick     Dead   Human
# 8            8   9          Agency Director     Dead   Human
# 9            9  10               Alan Rails     Dead   Human
# 10          10  11          Albert Einstein     Dead   Human
# 11          11  12                Alexander     Dead   Human
# 16          16  17                    Annie    Alive   Human
# 17          17  18            Antenna Morty    Alive   Human
# 18          18  19             Antenna Rick  unknown   Human
# ...

# %% [markdown]
# Q.9 Rename the Air Date column in the Episodes DataFrame to Air_Date.

# %%
episodes_data.rename(columns={'air_date':'Air_Date'},inplace=True)
episodes_data
# Out:
#     Unnamed: 0  id                                     name   Air_Date  \
# 0            0   1                                    PILOT 2013-12-02
# 1            1   2                            LAWNMOWER DOG 2013-12-09
# 2            2   3                             ANATOMY PARK 2013-12-16
# 3            3   4                   M. NIGHT SHAYM-ALIENS! 2014-01-13
# 4            4   5                     MEESEEKS AND DESTROY 2014-01-20
# 5            5   6                           RICK POTION #9 2014-01-27
# 6            6   7                      RAISING GAZORPAZORP 2014-03-10
# 7            7   8                            RIXTY MINUTES 2014-03-17
# 8            8   9          SOMETHING RICKED THIS WAY COMES 2014-03-24
# 9            9  10     CLOSE RICK-COUNTERS OF THE RICK KIND 2014-04-07
# 10          10  11                          RICKSY BUSINESS 2014-04-14
# 11          11  12                         A RICKLE IN TIME 2015-07-26
# ...

# %% [markdown]
# Q.10 Drop the Dimension column from the Locations DataFrame.

# %%
locations_data.drop('created',axis=1)
# Out:
#     Unnamed: 0  id                           name           type  \
# 0            0   1                  Earth (C-137)         Planet
# 1            1   2                       Abadango        Cluster
# 2            2   3               Citadel of Ricks  Space station
# 3            3   4              Worldender's lair         Planet
# 4            4   5                   Anatomy Park     Microverse
# 5            5   6         Interdimensional Cable             TV
# 6            6   7       Immortality Field Resort         Resort
# 7            7   8         Post-Apocalyptic Earth         Planet
# 8            8   9                   Purge Planet         Planet
# 9            9  10                   Venzenulon 7         Planet
# 10          10  11                        Bepis 9         Planet
# 11          11  12               Cronenberg Earth         Planet
# 12          12  13                       Nuptia 4         Planet
# ...

# %% [markdown]
# Q.11 Create a new column in the Characters DataFrame indicating whether a character is a 'Human' or not.

# %%
characters_data['life'] = characters_data.species=="Human"
characters_data
# Out:
#     Unnamed: 0  id                       name   status species  \
# 0            0   1               Rick Sanchez    Alive   Human
# 1            1   2                Morty Smith    Alive   Human
# 2            2   3               Summer Smith    Alive   Human
# 3            3   4                 Beth Smith    Alive   Human
# 4            4   5                Jerry Smith    Alive   Human
# 5            5   6  Abadango Cluster Princess    Alive   Alien
# 6            6   7           Abradolf Lincler  unknown   Human
# 7            7   8           Adjudicator Rick     Dead   Human
# 8            8   9            Agency Director     Dead   Human
# 9            9  10                 Alan Rails     Dead   Human
# 10          10  11            Albert Einstein     Dead   Human
# 11          11  12                  Alexander     Dead   Human
# 12          12  13               Alien Googah  unknown   Alien
# 13          13  14                Alien Morty  unknown   Alien
# ...

# %% [markdown]
# Q.12 Set the Name column as the index of the Locations DataFrame.

# %%
locations_data.index=locations_data.name
locations_data
# Out:
#                                Unnamed: 0  id                           name  \
# name
# Earth (C-137)                           0   1                  Earth (C-137)
# Abadango                                1   2                       Abadango
# Citadel of Ricks                        2   3               Citadel of Ricks
# Worldender's lair                       3   4              Worldender's lair
# Anatomy Park                            4   5                   Anatomy Park
# Interdimensional Cable                  5   6         Interdimensional Cable
# Immortality Field Resort                6   7       Immortality Field Resort
# Post-Apocalyptic Earth                  7   8         Post-Apocalyptic Earth
# Purge Planet                            8   9                   Purge Planet
# Venzenulon 7                            9  10                   Venzenulon 7
# Bepis 9                                10  11                        Bepis 9
# ...

# %% [markdown]
# Q. 13 Convert the Air Date column in the Episodes DataFrame to a DateTime format and find the most recent episode.

# %%
r=episodes_data.Air_Date.max()
episodes_data[episodes_data.Air_Date==r]
# Out:
#     Unnamed: 0  id                    name   Air_Date episode  \
# 19          19  20  LOOK WHO'S PURGING NOW 2015-09-27  S02E09
#
#                                            characters  \
# 19  ['https://rickandmortyapi.com/api/character/1'...
#
#                                            url                   created  \
# 19  https://rickandmortyapi.com/api/episode/20  2017-11-10T12:56:35.772Z
#
#    season
# 19    S02

# %% [markdown]
# # End!
